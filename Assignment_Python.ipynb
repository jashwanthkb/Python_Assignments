# %%
a=int(input("enter the num1:"))
b=int(input("enter the num2:"))
product=a*b
print(f"The Product of a={a} and b={b} is {product}")
# Out:
# enter the num1: 7
# enter the num2: 8
# The Product of a=7 and b=8 is 56

# %%
str1="My"
str2="Name"
str3="is"
str4="James"
print(str1,str2,str3,str4,sep="**")
# Out:
# My**Name**is**James

# %%
num = 8
print('%o' % num)
# Out:
# 10

# %%
num = 458.541315
print('%.2f' % num)
# Out:
# 458.54

# %%
num=[]
for i in range(0,5):
    print("Enter the values:",i,)
    item=float(input())
    num.append(item)
print("The List",num)
# Out:
# Enter the values: 0
#  2.3
# Enter the values: 1
#  4.6
# Enter the values: 2
#  9.0
# Enter the values: 3
#  2.2
# Enter the values: 4
#  5.1
# The List [2.3, 4.6, 9.0, 2.2, 5.1]

# %%
str1,str2,str3=input("enter three strings:").split()
print("Name1:",str1)
print("Name2:",str2)
print("Name3:",str3)
# Out:
# enter three strings: jash jeeva jashu
# Name1: jash
# Name2: jeeva
# Name3: jashu

# %%
#Assignment 11/03/2026

amount=float(input("Enter the amount:"))

if (amount>=100 and amount<=500):
    discount=amount*0.10
elif (amount>=500):
    discount=amount*0.20
else:
    discount=0
print("Discount:",discount)
print("Final amount is:",amount-discount)
# Out:
# Enter the amount: 350
# Discount: 35.0
# Final amount is: 315.0

# %%
color=input("Enter the color name:")
color_n=color.lower()
if (color_n=="red"):
    print("STOP")
elif(color_n=="yellow"):
    print("Ready to Go")
elif(color_n=="green"):
    print("GO")
else:
    print("invalid Color")
# Out:
# Enter the color name: YELLow
# Ready to Go

# %%
Marks=int(input("Enter the Students Marks:"))
if (Marks>100 or Marks<0):
    print("Invalid marks")
elif(Marks>=90):
    print("Grade A")
elif(Marks>=75 and Marks<90):
    print("Grade B")
elif(Marks>=50):
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter the Students Marks: 75
# Grade B

# %%
num=int(input("Enter the Number:"))
if(num%2==0 and num%5==0):
    print(f"the number {num} is even and divisible by 5")
elif(num%2==0):
    print("The number is even but not divisible by 5")
elif(num%5==0):
    print("The number is odd but divisible by 5")
else:
    print("The number is odd and not divisible by 5")
# Out:
# Enter the Number: 30
# the number 30 is even and divisible by 5

# %%
pwd=input("Enter the Password:")
if (len(pwd)>=8):
    print("Strong Password")
elif(len(pwd)>=5 and len(pwd)<8):
    print("Medium")
else:
    print("Weak Password")
# Out:
# Enter the Password: jgydf
# Medium

# %%
unit=int(input("enter the unit:"))
amount=0
if(unit<=100 and unit>0):
    amount=unit*0.5
elif(unit>100 and unit<=200):
    amount=(100*0.5)+((unit-100)*0.75)
elif(unit>200):
    amount=50+75+((unit-200)*1)
else:
    print("Invalid input")

print("Unit:",unit)
print("Total amount:",amount)

# %%
age=int(input("Enter the age of the Person:"))
income=float(input("Enter the monthly income of the person:"))
if((age>=21 and age<=60) and income>=5000):
    print("Person is eligible for loan")
else:
    print("Person is not eligible for loan")
# Out:
# Enter the age of the Person: 12
# Enter the monthly income of the person: 10000
# Person is not eligible for loan

# %%
weather=int(input("Enter the weather:"))
if (weather<0):
    print("Freezing Weather")
elif(weather<=20):
    print("cold weather")
elif(weather<=30):
    print("Warm weather")
else:
    print("Hot weather")
# Out:
# Enter the weather: -100
# Freezing Weather

# %%
n=int(input("Enter the number:"))
for i in range (1,11):
    print(f"{n}X{i}={n*i}")
# Out:
# Enter the number: 97
# 97X1=97
# 97X2=194
# 97X3=291
# 97X4=388
# 97X5=485
# 97X6=582
# 97X7=679
# 97X8=776
# 97X9=873
# 97X10=970

# %%
#nested if programs

#Write a Python program that takes a student’s marks as input.


marks=int(input("enter the marks:"))
if(marks>49):
    if(marks>=90):
        print("Grade A")
    elif(marks>=75):
        print("Grade B")
    else:
        print("Grade C")
else:
    print("Fail")
# Out:
# enter the marks: 50
# Grade C

# %%
bal=float(input("Enter the Account Balance:"))
amt=int(input("Enter the Amount to Withdraw:"))

if(bal>=amt):
    if(amt%100==0):
        print("Transaction Successful")
    else:
        print("Enter amount in multiple of 100")
else:
    print("Insufficient Balance")
# Out:
# Enter the Account Balance: 1000
# Enter the Amount to Withdraw: 100000
# Insufficient Balance

# %%
a=int(input("enter the side1 of Triangle:"))
b=int(input("enter the side2 of Triangle:"))
c=int(input("enter the side3 of Triangle:"))

if(a+b>c and b+c>a and c+a>b):
    if(a==b and b==c):
        print("Equilateral Triangle")
    elif(a==b or b==c or c==a):
        print("Isosceles Triangle")
    else:
        print("Scelene Triangle")
else:
    print("Not a Triangle")
# Out:
# enter the side1 of Triangle: 12
# enter the side2 of Triangle: 14
# enter the side3 of Triangle: 12
# Isosceles Triangle

# %%
age=int(input("Enter the age of voter:"))
c=input("enter the citizenship of vote:")
c_n=c.lower()

if (age>=18):
    if(c_n=="indian"):
        print("Eligible to Vote")
    else:
        print("Not Eligible (Non-Citizen)")
else:
    print("Not Eligible (Under age)")
# Out:
# Enter the age of voter: 23
# enter the citizenship of vote: AUS
# Not Eligible (Non-Citizen)

# %%
bill=int(input("enter the bill amount:"))

if(bill>=2000):
    if(bill>=10000 ):
        amt=bill-bill*(20/100)
        print(amt)
    elif(bill>=5000):
        amt=bill-bill*(10/100)
        print(amt)
    else:
        amt=bill-bill*(5/100)
        print(amt)
else:
    print("No Discount")
# Out:
# enter the bill amount: 10000
# 8000.0

# %%
1. Employee Salary Increment
A company gives a 5% yearly increment to an employee’s salary. Write a for loop to calculate the employee’s salary for the next 10 years starting from ₹50,000.


2. Class Attendance Percentage
A student attended 18 out of 25 classes. Write a for loop to calculate and display the attendance percentage for each class attended (like running count).


3. Product Discount Prices
A store applies a 10% discount on all products. Given a list of original prices [100, 250, 400, 560, 700], use a for loop to calculate and print the discounted prices.


4. Monthly Savings Growth
A person saves ₹1,000 every month. Write a for loop to calculate and display the total savings at the end of each month for 12 months.


5. Electricity Bill Calculation
The electricity cost is ₹5 per unit. If a household consumes [120, 135, 150, 160, 145] units over 5 months, use a for loop to calculate the bill for each month.


6. Student Marks Percentage
A student scored marks in 5 subjects: [78, 85, 90, 66, 72]. Use a for loop to calculate the percentage (out of 100) for each subject.

# %%
salary=int(input("enter the salary:"))
for i in range(1,11):
    salary=salary+salary*0.05
    print("Year",i,"Salary",salary)
# Out:
# enter the salary: 100000
# Year 1 Salary 105000.0
# Year 2 Salary 110250.0
# Year 3 Salary 115762.5
# Year 4 Salary 121550.625
# Year 5 Salary 127628.15625
# Year 6 Salary 134009.5640625
# Year 7 Salary 140710.042265625
# Year 8 Salary 147745.54437890626
# Year 9 Salary 155132.82159785158
# Year 10 Salary 162889.46267774416

# %%
cls=int(input("enter the attended classes:"))
Total_cls=25
for i in range (1,cls+1):
    per=i/25*100
    print("class",i,"percentage",per,"%")
# Out:
# enter the attended classes: 18
# class 1 percentage 4.0 %
# class 2 percentage 8.0 %
# class 3 percentage 12.0 %
# class 4 percentage 16.0 %
# class 5 percentage 20.0 %
# class 6 percentage 24.0 %
# class 7 percentage 28.000000000000004 %
# class 8 percentage 32.0 %
# class 9 percentage 36.0 %
# class 10 percentage 40.0 %
# class 11 percentage 44.0 %
# class 12 percentage 48.0 %
# class 13 percentage 52.0 %
# class 14 percentage 56.00000000000001 %
# class 15 percentage 60.0 %
# class 16 percentage 64.0 %
# class 17 percentage 68.0 %
# class 18 percentage 72.0 %

# %%
prices = [100, 250, 400, 560, 700]

for price in prices:
    discount_price = price - price * 0.10
    print("Discounted price =", discount_price)
# Out:
# Discounted price = 90.0
# Discounted price = 225.0
# Discounted price = 360.0
# Discounted price = 504.0
# Discounted price = 630.0

# %%
saving = 1000
total = 0

for month in range(1, 13):
    total = total + saving
    print("Month", month, "Total Savings =", total)
# Out:
# Month 1 Total Savings = 1000
# Month 2 Total Savings = 2000
# Month 3 Total Savings = 3000
# Month 4 Total Savings = 4000
# Month 5 Total Savings = 5000
# Month 6 Total Savings = 6000
# Month 7 Total Savings = 7000
# Month 8 Total Savings = 8000
# Month 9 Total Savings = 9000
# Month 10 Total Savings = 10000
# Month 11 Total Savings = 11000
# Month 12 Total Savings = 12000

# %%
units = [120, 135, 150, 160, 145]

for u in units:
    bill = u * 5
    print("Units:", u, "Bill =", bill)
# Out:
# Units: 120 Bill = 600
# Units: 135 Bill = 675
# Units: 150 Bill = 750
# Units: 160 Bill = 800
# Units: 145 Bill = 725

# %%
marks = [78, 85, 90, 66, 72]

for m in marks:
    percentage = (m / 100) * 100
    print("Percentage =", percentage, "%")
# Out:
# Percentage = 78.0 %
# Percentage = 85.0 %
# Percentage = 90.0 %
# Percentage = 66.0 %
# Percentage = 72.0 %
